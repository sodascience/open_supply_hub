# %% [markdown]
# ### Prerequirements
#
# Before extracting any data, contact Open Supply Hub to obtain an API key or the JSON files.

# %% [markdown]
# # Option 1: Parse the JSON files
#
# Extracts the information from the JSON files contained in `data_directory`, saves the results into `output_directory` in two files, one containing the facilities, one containing the contributions over time

# %%
# import the script
from process_json import get_data
import pandas as pd

## set up paths
# directory containing the json files
data_directory = '../data/json_files'

# output files to store results
filename_facilities = '../results/facilities.csv'
filename_contributions = '../results/contributions.csv'

# %%
# Get data about facilities and contributors,
# and save them to csv files in output directory
get_data(data_directory, 
         filename_facilities=filename_facilities,
         filename_contributions=filename_contributions)

# %%
# inspect the facilities file
pd.read_csv(filename_facilities, sep='\t', nrows=5)
# Out:
#              os_id                                    facility_name  \
# HUU THANH HOUSEHOLD
# 1  CN20213347PTKW6       \t\nRushan HempFortex Industries Co., Ltd.
# 2  BD20222851G47VJ  \tAl-Karam Towel Industries (Pvt.) Ltd. Unit-II
# 3  CN2021252KMAV3E             \tFUJIAN CHANGYUAN TEXTILE CO., LTD.
# 4  VN2022293X36514                 \tMaxport No 5 - Nam Dinh Branch
#
#                                              address country_code  \
# 0  A5/140B, Hamlet 1, Tan Nhut commune, Binh Chan...           VN
# 1       TOWN WEIHAI CITY, DAGUSHAN, Shandong, 264507           CN
# 2           \t\nپلاٹ#ڈی-18 سائٹ سپر ہائی وے اسکیم #3           BD
# 3  Hunan District, Airport Industrial Zone, Hunan...           CN
# 4                    Highway 10, Loc Vuong, Nam Dinh           VN
#
#   country_name        lat         lng is_closed
# 0      Vietnam  10.738181  106.536036
# 1        China  36.919551  121.636611
# 2   Bangladesh  23.684994   90.356331
# 3        China  41.714914  123.449714
# 4      Vietnam  20.444519  106.159501

# %%
# inspect the contributions file
pd.read_csv(filename_contributions, sep='\t', nrows=5)
# Out:
#   contributor_id                contributor_name            os_id  \
# 0          848.0   HONG  SHENG SHOES COMPANY LTD  CN2021256J1YK18
# 1          848.0   HONG  SHENG SHOES COMPANY LTD  CN2021256J1YK18
# 2         2483.0    M.C.K  INTERNATIONAL LIMITED  CN2019085FN2EDB
# 3         2483.0    M.C.K  INTERNATIONAL LIMITED  CN2020009GJW6QS
# 4         2483.0    M.C.K  INTERNATIONAL LIMITED  CN2020148BR342E
#
#                      supplier_name contribution_date  \
# 0     HONG SHENG SHOES COMPANY LTD        2022-10-28
# 1     HONG SHENG SHOES COMPANY LTD        2022-10-28
# 2     Hangzhou Luke Shoes Co. Ltd.        2022-10-28
# 3   Wenzhou Aoliwei Shoes Co. Ltd.        2022-02-08
# 4  Hangzhou Zhongpu Shoes Co. Ltd.        2022-02-08
#
#                                              address number_of_workers_min  \
# 0  GEHAI INDUSTRIAL ZONE YANBU TOWN, NANHAI DISTR...
# 1  GEHAI INDUSTRIAL ZONE YANBU TOWN, NANHAI DISTR...
# 2  Jingyou Village, Puyang Town,Xiaoshan District...
# 3  NO.58,Xingping Road, Puzhong Street, Longwan D...
# 4  Anshan Village,Puyang Town,Xiaoshan District,H...
#
#   number_of_workers_max facility_type processing_type parent_company  \
# 0
# 1
# 2
# 3
# 4
#
#   product_type
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Option 2: Scrape data via API
#
# Extracts the information from the API in the same format available in OpenSupplyHub, with one file containing the contributions and where the time-invariant information on the facilities is duplicated.

# %%
import pandas as pd
from process_api import get_data

# %%
# set where you want to save the data 
output_directory = "../results"

# you will need a session ID (do not use this wihout API access from OpenSupplyHub)
cookies = {
    'sessionid': 'write_here_your_session_id',
}

# %%
# get data (by default to )
get_data(cookies, filename="data/output_data.tsv.gz")

# %%
# inspect data
pd.read_csv("data/output_data.tsv.gz", sep='\t', low_memory=False, nrows=10)
# Out:
#              os_id contribution_date               name  \
# 0  BD2020212VEDNJC        2020-07-30      2T's Creation
# 1  BD2020212VEDNJC        2022-05-16
# 2  BD2020212VEDNJC        2022-05-16
# 3  BD2020212VEDNJC        2021-11-29
# 4  BD2019248GNVQ6X        2019-09-05  3-A Fashions Ltd.
#
#                                              address country_code  \
# 0  Plot 1241 (3rd Floor), Begum Rokeya Sarani, Ea...           BD
# 1
# 2
# 3
# 4  Madrasha Road, Khejur Bagan, Ashulia, Savar, D...           BD
#
#   country_name         lat        lng   sector  \
# 0   Bangladesh  23.8006254  90.371022  Apparel
# 1                                      Apparel
# 2                                      Apparel
# 3                                      Apparel
# 4   Bangladesh  23.8909633  90.329906  Apparel
#
#                                   contributor (list) number_of_workers  \
# 0  PPE: Mapped in Bangladesh (PPE: Mapped in Bang...
# 1  BRAC University (Mapped in Bangladesh: Export ...
# 2  An Academic / Researcher / Journalist / Studen...
# 3                              BRAC University (API)
# 4  BRAC University (Mapped in Bangladesh: Export-...
#
#   parent_company processing_type_facility_type_raw facility_type  \
# 0
# 1
# 2
# 3
# 4
#
#   processing_type product_type is_closed  \
# 0                                  False
# 1
# 2
# 3
# 4                                  False
#
#                                contributor_type
# 0  Academic / Researcher / Journalist / Student
# 1  Academic / Researcher / Journalist / Student
# 2  Academic / Researcher / Journalist / Student
# 3  Academic / Researcher / Journalist / Student
# 4  Academic / Researcher / Journalist / Student
